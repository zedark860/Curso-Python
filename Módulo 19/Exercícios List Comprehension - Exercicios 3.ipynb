# %% [markdown]
# # Exercícios
#
# ## 1. Tamanho do Pedido de Compras
#
# Nesse exercício vamos avaliar o estoque de uma empresa. Vamos considerar que todos os produtos dessa empresa são comprados em lotes de 500 unidades.
#
# - Caso o estoque esteja abaixo de 1000 unidades, devemos fazer um pedido de 500 unidades.
# - Caso o estoque esteja abaixo de 200 unidades, devemos fazer um pedido de 1000 unidades.
#
# Defina o valor a ser pedido de cada produto para enviar ao time de compras.

# %%
estoque = [('BSA2199',396),('PPF5239',251),('BSA1212',989),('PPF2154',449),('BEB3410',241),('PPF8999',527),('EMB9591',601),('BSA2006',314),('EMB3604',469),('EMB2070',733),('PPF9018',339),('PPF1468',906),('BSA5819',291),('PPF8666',850),('BEB2983',353),('BEB5877',456),('PPF5008',963),('PPF3877',185),('PPF7321',163),('BSA8833',644),('PPF4980',421),('PPF3063',757),('BSA2089',271),('BSA8398',180),('EMB4622',515),('EMB9814',563),('PPF3784',229),('PPF2398',270),('BEB3211',181),('PPF8655',459),('PPF1874',799),('PPF8789',126),('PPF6324',375),('EMB9290',883),('BSA5516',555),('BSA8451',243),('BSA8213',423)]

lista_pedido = []
for produto, qtde in estoque:
    if qtde < 200:
        lista_pedido.append(1000)
    else:
        lista_pedido.append(500)

lista_produtos = [(1000, produto) if qtde < 200 else (500, produto) for produto, qtde in estoque]

for unidade, produto in lista_produtos:
    print(f'O produto {produto} está abaixo do estoque e é necessário fazer o pedido de {unidade} unidades')
# Out:
# O produto BSA2199 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF5239 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BSA1212 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF2154 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BEB3410 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF8999 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto EMB9591 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BSA2006 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto EMB3604 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto EMB2070 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF9018 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF1468 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BSA5819 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF8666 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BEB2983 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BEB5877 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF5008 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF3877 está abaixo do estoque e é necessário fazer o pedido de 1000 unidades
# O produto PPF7321 está abaixo do estoque e é necessário fazer o pedido de 1000 unidades
# O produto BSA8833 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF4980 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF3063 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BSA2089 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BSA8398 está abaixo do estoque e é necessário fazer o pedido de 1000 unidades
# O produto EMB4622 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto EMB9814 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF3784 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF2398 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BEB3211 está abaixo do estoque e é necessário fazer o pedido de 1000 unidades
# O produto PPF8655 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF1874 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto PPF8789 está abaixo do estoque e é necessário fazer o pedido de 1000 unidades
# O produto PPF6324 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto EMB9290 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BSA5516 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BSA8451 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
# O produto BSA8213 está abaixo do estoque e é necessário fazer o pedido de 500 unidades
