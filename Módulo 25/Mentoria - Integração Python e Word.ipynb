# %%
from docx import Document

# criando o documento no Python
documento = Document()

faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Lira,

O faturamento da empresa ontem foi de R${faturamento}

Tamo junto, abs.
"""

paragrafo = documento.add_paragraph(texto)

# implementando tudo que fizemos no Python no Texto.docx
documento.save("Texto.docx")

# %% [markdown]
# ### formatação

# %%
# Para formatação de texto
from docx.shared import Pt, RGBColor, Cm # Valores de formatação
from docx.enum.style import WD_STYLE_TYPE # Permite criar estilo de formatação

paragrafo.style = documento.styles.add_style("EstiloLira", WD_STYLE_TYPE.PARAGRAPH)
# É melhor fazer o estilo no word e utilizar o template por aqui
paragrafo.style.font.name = "Algerian"
paragrafo.style.font.size = Pt(15)
paragrafo.style.font.bold = True
paragrafo.style.font.italic = True
paragrafo.style.font.underline = True
paragrafo.style.font.color.rgb = RGBColor(255, 0, 0)

# %%
# Passando o estilo criado anteriormente para o parágrafo novo
paragrafo = documento.add_paragraph("PS: A quantidade de produtos vendidos foi de 10", 'Heading 5')

# %%
# Visualizando todos o estilos disponíveis
for estilo in documento.styles:
    print(estilo)
# Out:
# _ParagraphStyle('Normal') id: 2431920623184
# _ParagraphStyle('Header') id: 2431920625536
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# _ParagraphStyle('Footer') id: 2431920625536
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# _ParagraphStyle('Heading 1') id: 2431920625536
# _ParagraphStyle('Heading 2') id: 2431920623184
# _ParagraphStyle('Heading 3') id: 2431920625536
# _ParagraphStyle('Heading 4') id: 2431920623184
# _ParagraphStyle('Heading 5') id: 2431920625536
# _ParagraphStyle('Heading 6') id: 2431920623184
# _ParagraphStyle('Heading 7') id: 2431920625536
# _ParagraphStyle('Heading 8') id: 2431920623184
# _ParagraphStyle('Heading 9') id: 2431920625536
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# _TableStyle('Normal Table') id: 2431920625536
# <docx.styles.style._NumberingStyle object at 0x0000023639C3CE50>
# _ParagraphStyle('No Spacing') id: 2431920625536
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# _ParagraphStyle('Title') id: 2431920625536
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# _ParagraphStyle('Subtitle') id: 2431920625536
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# _ParagraphStyle('List Paragraph') id: 2431920625536
# _ParagraphStyle('Body Text') id: 2431920623184
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# _ParagraphStyle('Body Text 2') id: 2431920623184
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# _ParagraphStyle('Body Text 3') id: 2431920623184
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# _ParagraphStyle('List') id: 2431920623184
# _ParagraphStyle('List 2') id: 2431920625536
# _ParagraphStyle('List 3') id: 2431920623184
# _ParagraphStyle('List Bullet') id: 2431920625536
# _ParagraphStyle('List Bullet 2') id: 2431920623184
# _ParagraphStyle('List Bullet 3') id: 2431920625536
# _ParagraphStyle('List Number') id: 2431920623184
# _ParagraphStyle('List Number 2') id: 2431920625536
# _ParagraphStyle('List Number 3') id: 2431920623184
# _ParagraphStyle('List Continue') id: 2431920625536
# _ParagraphStyle('List Continue 2') id: 2431920623184
# _ParagraphStyle('List Continue 3') id: 2431920625536
# _ParagraphStyle('macro') id: 2431920623184
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# _ParagraphStyle('Quote') id: 2431920623184
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# _ParagraphStyle('Caption') id: 2431920623184
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# _ParagraphStyle('Intense Quote') id: 2431920625536
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3CE50>
# <docx.styles.style.CharacterStyle object at 0x0000023639C3D780>
# _ParagraphStyle('TOC Heading') id: 2431920623184
# _TableStyle('Table Grid') id: 2431920625536
# _TableStyle('Light Shading') id: 2431920623184
# _TableStyle('Light Shading Accent 1') id: 2431920625536
# _TableStyle('Light Shading Accent 2') id: 2431920623184
# _TableStyle('Light Shading Accent 3') id: 2431920625536
# _TableStyle('Light Shading Accent 4') id: 2431920623184
# _TableStyle('Light Shading Accent 5') id: 2431920625536
# _TableStyle('Light Shading Accent 6') id: 2431920623184
# _TableStyle('Light List') id: 2431920625536
# _TableStyle('Light List Accent 1') id: 2431920623184
# _TableStyle('Light List Accent 2') id: 2431920625536
# _TableStyle('Light List Accent 3') id: 2431920623184
# _TableStyle('Light List Accent 4') id: 2431920625536
# _TableStyle('Light List Accent 5') id: 2431920623184
# _TableStyle('Light List Accent 6') id: 2431920625536
# _TableStyle('Light Grid') id: 2431920623184
# _TableStyle('Light Grid Accent 1') id: 2431920625536
# _TableStyle('Light Grid Accent 2') id: 2431920623184
# _TableStyle('Light Grid Accent 3') id: 2431920625536
# _TableStyle('Light Grid Accent 4') id: 2431920623184
# _TableStyle('Light Grid Accent 5') id: 2431920625536
# _TableStyle('Light Grid Accent 6') id: 2431920623184
# _TableStyle('Medium Shading 1') id: 2431920625536
# _TableStyle('Medium Shading 1 Accent 1') id: 2431920623184
# _TableStyle('Medium Shading 1 Accent 2') id: 2431920625536
# _TableStyle('Medium Shading 1 Accent 3') id: 2431920623184
# _TableStyle('Medium Shading 1 Accent 4') id: 2431920625536
# _TableStyle('Medium Shading 1 Accent 5') id: 2431920623184
# _TableStyle('Medium Shading 1 Accent 6') id: 2431920625536
# _TableStyle('Medium Shading 2') id: 2431920623184
# _TableStyle('Medium Shading 2 Accent 1') id: 2431920625536
# _TableStyle('Medium Shading 2 Accent 2') id: 2431920623184
# _TableStyle('Medium Shading 2 Accent 3') id: 2431920625536
# _TableStyle('Medium Shading 2 Accent 4') id: 2431920623184
# _TableStyle('Medium Shading 2 Accent 5') id: 2431920625536
# _TableStyle('Medium Shading 2 Accent 6') id: 2431920623184
# _TableStyle('Medium List 1') id: 2431920625536
# _TableStyle('Medium List 1 Accent 1') id: 2431920623184
# _TableStyle('Medium List 1 Accent 2') id: 2431920625536
# _TableStyle('Medium List 1 Accent 3') id: 2431920623184
# _TableStyle('Medium List 1 Accent 4') id: 2431920625536
# _TableStyle('Medium List 1 Accent 5') id: 2431920623184
# _TableStyle('Medium List 1 Accent 6') id: 2431920625536
# _TableStyle('Medium List 2') id: 2431920623184
# _TableStyle('Medium List 2 Accent 1') id: 2431920625536
# _TableStyle('Medium List 2 Accent 2') id: 2431920623184
# _TableStyle('Medium List 2 Accent 3') id: 2431920625536
# _TableStyle('Medium List 2 Accent 4') id: 2431920623184
# _TableStyle('Medium List 2 Accent 5') id: 2431920625536
# _TableStyle('Medium List 2 Accent 6') id: 2431920623184
# _TableStyle('Medium Grid 1') id: 2431920625536
# _TableStyle('Medium Grid 1 Accent 1') id: 2431920623184
# _TableStyle('Medium Grid 1 Accent 2') id: 2431920625536
# _TableStyle('Medium Grid 1 Accent 3') id: 2431920623184
# _TableStyle('Medium Grid 1 Accent 4') id: 2431920625536
# _TableStyle('Medium Grid 1 Accent 5') id: 2431920623184
# _TableStyle('Medium Grid 1 Accent 6') id: 2431920625536
# _TableStyle('Medium Grid 2') id: 2431920623184
# _TableStyle('Medium Grid 2 Accent 1') id: 2431920625536
# _TableStyle('Medium Grid 2 Accent 2') id: 2431920623184
# _TableStyle('Medium Grid 2 Accent 3') id: 2431920625536
# _TableStyle('Medium Grid 2 Accent 4') id: 2431920623184
# _TableStyle('Medium Grid 2 Accent 5') id: 2431920625536
# _TableStyle('Medium Grid 2 Accent 6') id: 2431920623184
# _TableStyle('Medium Grid 3') id: 2431920625536
# _TableStyle('Medium Grid 3 Accent 1') id: 2431920623184
# _TableStyle('Medium Grid 3 Accent 2') id: 2431920625536
# _TableStyle('Medium Grid 3 Accent 3') id: 2431920623184
# _TableStyle('Medium Grid 3 Accent 4') id: 2431920625536
# _TableStyle('Medium Grid 3 Accent 5') id: 2431920623184
# _TableStyle('Medium Grid 3 Accent 6') id: 2431920625536
# _TableStyle('Dark List') id: 2431920623184
# _TableStyle('Dark List Accent 1') id: 2431920625536
# _TableStyle('Dark List Accent 2') id: 2431920623184
# _TableStyle('Dark List Accent 3') id: 2431920625536
# _TableStyle('Dark List Accent 4') id: 2431920623184
# _TableStyle('Dark List Accent 5') id: 2431920625536
# _TableStyle('Dark List Accent 6') id: 2431920623184
# _TableStyle('Colorful Shading') id: 2431920625536
# _TableStyle('Colorful Shading Accent 1') id: 2431920623184
# _TableStyle('Colorful Shading Accent 2') id: 2431920625536
# _TableStyle('Colorful Shading Accent 3') id: 2431920623184
# _TableStyle('Colorful Shading Accent 4') id: 2431920625536
# _TableStyle('Colorful Shading Accent 5') id: 2431920623184
# _TableStyle('Colorful Shading Accent 6') id: 2431920625536
# _TableStyle('Colorful List') id: 2431920623184
# _TableStyle('Colorful List Accent 1') id: 2431920625536
# _TableStyle('Colorful List Accent 2') id: 2431920623184
# _TableStyle('Colorful List Accent 3') id: 2431920625536
# _TableStyle('Colorful List Accent 4') id: 2431920623184
# _TableStyle('Colorful List Accent 5') id: 2431920625536
# _TableStyle('Colorful List Accent 6') id: 2431920623184
# _TableStyle('Colorful Grid') id: 2431920625536
# _TableStyle('Colorful Grid Accent 1') id: 2431920623184
# _TableStyle('Colorful Grid Accent 2') id: 2431920625536
# _TableStyle('Colorful Grid Accent 3') id: 2431920623184
# _TableStyle('Colorful Grid Accent 4') id: 2431920625536
# _TableStyle('Colorful Grid Accent 5') id: 2431920623184
# _TableStyle('Colorful Grid Accent 6') id: 2431920625536
# _ParagraphStyle('EstiloLira') id: 2431920623184

# %% [markdown]
# ### Aproveitando um template do word

# %%
template = Document("template.docx")

# %%
paragrafo = template.add_paragraph("Contrato de Prestação de Serviço", "NovoEstiloABNT")
template.save("NovoArquivo.docx")

# %% [markdown]
# ### Adicionar texto com edição dentro do texto

# %%
from docx import Document

# criando o documento no Python
documento = Document()

faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Lira,

O faturamento da empresa ontem foi de """

texto_final = "Tamo junto, abs."

paragrafo = documento.add_paragraph(texto)

paragrafo.add_run(f"R${faturamento}").bold = True

paragrafo = documento.add_paragraph(texto_final)

documento.save("Texto.docx")

# %% [markdown]
# ### Controle de Margem e Seções

# %%
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# criando o documento no Python
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)

faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Lira,

O faturamento da empresa ontem foi de R${faturamento}

Tamo junto, abs.
"""

paragrafo = documento.add_paragraph(texto)

paragrafo.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

documento.save("Texto.docx")

# %% [markdown]
# ### Inserir Imagem

# %%
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# criando o documento no Python
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)

faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Lira,

O faturamento da empresa ontem foi de R${faturamento}

Tamo junto, abs.
"""

paragrafo = documento.add_paragraph(texto)

imagem = documento.add_picture("imagem.png", width=Cm(4), height=Cm(4))

imagem.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

documento.save("Texto.docx")

# %% [markdown]
# ### Inserir Tabela

# %%
documento = Document()

records = (
    (3, '101', 'Spam'),
    (7, '422', 'Eggs'),
    (4, '631', 'Spam, spam, eggs, and spam')
)

table = documento.add_table(rows=1, cols=3, style="Light Grid Accent 1")
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Qty'
hdr_cells[1].text = 'Id'
hdr_cells[2].text = 'Desc'
for qty, id, desc in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id
    row_cells[2].text = desc
    
    
documento.save("Texto.docx")

# %% [markdown]
# ### Adaptar um documento

# %%
from datetime import datetime
from docx import Document

contrato = Document("Contrato.docx")

data_atual = datetime.today()

nome = "Davi Nascimento"
item1 = "Serviço de Treinamento em Excel"
item2 = "Apostila Completa de Excel"
item3 = "Serviço de Treinamentos de Python"

dicionario_valores = {
    "XXXX": nome,
    "YYYY": item1,
    "ZZZZ": item2,
    "WWWW": item3,
    "DD": str(data_atual.day),
    "MM": str(data_atual.month),
    "AAAA": str(data_atual.year)
}

for paragrafo in contrato.paragraphs:
    for placeholder in dicionario_valores:
        if placeholder in paragrafo.text:
            paragrafo.text = paragrafo.text.replace(placeholder, dicionario_valores[placeholder])

contrato.save("Contrato Atualizado.docx")
