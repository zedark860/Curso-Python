# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\Pagina Hashtag.html"
navegador.get(arquivo)

# %% [markdown]
# #### Botão que abre outra janela

# %%
navegador.find_element(By.XPATH, "/html/body/section[2]/div/div[6]/figure/a/img").click()

# %% [markdown]
# ### Outra aba

# %%
# isso é uma lista de abas
# o indice da lista é de acordo com a quantidade de páginas abertas, mesmo sentido de uma lista
aba_original = navegador.window_handles[0]
nova_aba = navegador.window_handles[1]

# trocando de aba
navegador.switch_to.window(nova_aba)

# %%
navegador.find_element(By.NAME, "firstname").send_keys("Teste")
navegador.find_element(By.NAME, "email").send_keys("Teste@gmail.com")

# %%
# voltando para outra aba
navegador.switch_to.window(aba_original)

# %%
# para saber todas as abas
for aba in navegador.window_handles:
    navegador.switch_to.window(aba)
    print(navegador.title)
# Out:
# Todos os Cursos Hashtag Treinamentos
# Curso Power BI Avançado | Projetos Reais e +80h de Conteúdo
# DevTools
# Curso de Excel Completo: Excel Impressionador

# %% [markdown]
# ### Outra janela

# %%
lista_abas = navegador.window_handles
print(len(lista_abas))
# Out:
# 4

# %%
aba_excel = navegador.window_handles[3]
navegador.switch_to.window(aba_excel)

# %%
navegador.find_element(By.NAME, "firstname").send_keys("Teste")
navegador.find_element(By.NAME, "email").send_keys("Teste@gmail.com")

# %%
# fechando aba específica
navegador.close()

# %%
# todas as abas
navegador.quit()
